# %%
import gymnasium as gym
import env  # registers my-four-room-v0
import numpy as np
import wandb
import matplotlib.pyplot as plt

from morl_baselines.multi_policy.pareto_q_learning.pql import PQL
from wrappers import CombineWrapper, Convert2DStateWrapper
from utils import visualize_front_general
import time

# %%
# Experiment config
PROJECT = "MORL-Baselines"
RUN_NAME = f"pql-my-four-room-interpretations-per-value-weight-{int(time.time())}"

TOTAL_TIMESTEPS = int(1e4)
SEED = 42
N_WEIGHTS = 10
MAX_EPISODE_STEPS = 100

# After CombineWrapper, rewards are [triangle, circle]
REF_POINT = np.array([0.0, 0.0], dtype=np.float32)
VALUE_WEIGHTS = np.linspace(0.0, 1.0, N_WEIGHTS)

# %%
all_fronts = {}

with wandb.init(project=PROJECT, name=RUN_NAME, config={
    "total_timesteps": TOTAL_TIMESTEPS,
    "seed": SEED,
    "n_weights": N_WEIGHTS,
}):
    for i, w_blue in enumerate(VALUE_WEIGHTS):
        w_red = 1.0 - w_blue
        weight_vec = np.array([w_blue, w_red], dtype=np.float32)

        train_env = CombineWrapper(Convert2DStateWrapper(gym.wrappers.TimeLimit(gym.make("my-four-room-v0"), max_episode_steps=MAX_EPISODE_STEPS)), weight_vec)
        eval_env = CombineWrapper(Convert2DStateWrapper(gym.wrappers.TimeLimit(gym.make("my-four-room-v0"), max_episode_steps=MAX_EPISODE_STEPS)), weight_vec)

        agent = PQL(
            env=train_env,
            ref_point=REF_POINT,
            gamma=0.99,
            initial_epsilon=1.0,
            epsilon_decay_steps=TOTAL_TIMESTEPS,
            final_epsilon=0.05,
            seed=SEED,
            log=True,
        )

        pareto_front = agent.train(
            total_timesteps=TOTAL_TIMESTEPS,
            eval_env=eval_env,
            ref_point=REF_POINT,
            log_every=max(1, TOTAL_TIMESTEPS // 10),
            action_eval="hypervolume",
        )

        front_arr = np.array(list(pareto_front), dtype=np.float32)
        all_fronts[float(w_blue)] = front_arr

        # Per-weight logging in one shared run
        wandb.log({
            "outer_idx": i,
            "value_w_blue": float(w_blue),
            "value_w_red": float(w_red),
            "front_size": int(len(front_arr)),
        })

        visualize_front_general(front_arr, columns=["triangle", "circle"])

        print(
            f"[{i + 1}/{N_WEIGHTS}] value weights (blue={w_blue:.3f}, red={w_red:.3f}) -> "
            f"front size={len(front_arr)}"
        )

        train_env.close()
        eval_env.close()

    wandb.log({"n_fronts_collected": len(all_fronts)})

    # Aggregate visualization logged in the same run
    fig, ax = plt.subplots(figsize=(8, 6))
    for w_blue, front in all_fronts.items():
        if len(front) == 0:
            continue
        ax.scatter(front[:, 0], front[:, 1], alpha=0.7, label=f"w_blue={w_blue:.2f}")

    ax.set_xlabel("triangle interpretation")
    ax.set_ylabel("circle interpretation")
    ax.set_title("Pareto fronts over interpretations per value scalarization weight")
    ax.legend(loc="best", fontsize=8, ncol=2)
    ax.grid(True, alpha=0.3)
    plt.tight_layout()

    wandb.log({"all_fronts_overlay": wandb.Image(fig)})
    plt.close(fig)

print("Done. Collected fronts for", len(all_fronts), "value weights.")
# Out:
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/cardinality</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/eum</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/hypervolume</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>front_size</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁▂▂▃▃▃▃▄▄▅▅▆▆▆▆▇▇██████</td></tr><tr><td>n_fronts_collected</td><td>▁</td></tr><tr><td>outer_idx</td><td>▁</td></tr><tr><td>value_w_blue</td><td>▁</td></tr><tr><td>value_w_red</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/cardinality</td><td>1</td></tr><tr><td>eval/eum</td><td>0</td></tr><tr><td>eval/hypervolume</td><td>0</td></tr><tr><td>front_size</td><td>1</td></tr><tr><td>global_step</td><td>10</td></tr><tr><td>n_fronts_collected</td><td>1</td></tr><tr><td>outer_idx</td><td>0</td></tr><tr><td>value_w_blue</td><td>0.5</td></tr><tr><td>value_w_red</td><td>0.5</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">my-four-room-v0__Pareto Q-Learning__42__1775654684</strong> at: <a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/89jumj39' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines/runs/89jumj39</a><br> View project at: <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines</a><br>Synced 6 W&B file(s), 12 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260408_152446-89jumj39\logs</code>
# Tracking run with wandb version 0.24.2
# Run data is saved locally in <code>c:\Users\skakr\Documents\Programming\md-morl\wandb\run-20260408_152543-pewxb34a</code>
# Syncing run <strong><a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/pewxb34a' target="_blank">pql-my-four-room-interpretations-per-value-weight-1775654638</a></strong> to <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines</a>
#  View run at <a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/pewxb34a' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines/runs/pewxb34a</a>
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">pql-my-four-room-interpretations-per-value-weight-1775654638</strong> at: <a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/pewxb34a' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines/runs/pewxb34a</a><br> View project at: <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260408_152543-pewxb34a\logs</code>
# Tracking run with wandb version 0.24.2
# Run data is saved locally in <code>c:\Users\skakr\Documents\Programming\md-morl\wandb\run-20260408_152547-htm1cg5l</code>
# Syncing run <strong><a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/htm1cg5l' target="_blank">my-four-room-v0__Pareto Q-Learning__42__1775654746</a></strong> to <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines</a>
#  View run at <a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/htm1cg5l' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines/runs/htm1cg5l</a>
# c:\Users\skakr\Documents\Programming\md-morl\.venv\Lib\site-packages\gymnasium\utils\passive_env_checker.py:245: UserWarning: WARN: The reward returned by `step()` must be a float, int, np.integer or np.floating, actual type: <class 'numpy.ndarray'>
#   logger.warn(
# [1/10] value weights (blue=0.000, red=1.000) -> front size=1
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/cardinality</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/eum</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/hypervolume</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>front_size</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁▂▂▃▃▃▃▄▄▅▅▆▆▆▆▇▇████</td></tr><tr><td>outer_idx</td><td>▁</td></tr><tr><td>value_w_blue</td><td>▁</td></tr><tr><td>value_w_red</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/cardinality</td><td>1</td></tr><tr><td>eval/eum</td><td>0</td></tr><tr><td>eval/hypervolume</td><td>0</td></tr><tr><td>front_size</td><td>1</td></tr><tr><td>global_step</td><td>100</td></tr><tr><td>outer_idx</td><td>0</td></tr><tr><td>value_w_blue</td><td>0</td></tr><tr><td>value_w_red</td><td>1</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">my-four-room-v0__Pareto Q-Learning__42__1775654746</strong> at: <a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/htm1cg5l' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines/runs/htm1cg5l</a><br> View project at: <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines</a><br>Synced 6 W&B file(s), 11 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260408_152547-htm1cg5l\logs</code>
# Tracking run with wandb version 0.24.2
# Run data is saved locally in <code>c:\Users\skakr\Documents\Programming\md-morl\wandb\run-20260408_152600-v55p9y0y</code>
# Syncing run <strong><a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/v55p9y0y' target="_blank">my-four-room-v0__Pareto Q-Learning__42__1775654758</a></strong> to <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines</a>
#  View run at <a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/v55p9y0y' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines/runs/v55p9y0y</a>
# c:\Users\skakr\Documents\Programming\md-morl\.venv\Lib\site-packages\gymnasium\utils\passive_env_checker.py:245: UserWarning: WARN: The reward returned by `step()` must be a float, int, np.integer or np.floating, actual type: <class 'numpy.ndarray'>
#   logger.warn(
# [2/10] value weights (blue=0.111, red=0.889) -> front size=1
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/cardinality</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/eum</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/hypervolume</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>front_size</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁▂▂▃▃▃▃▄▄▅▅▆▆▆▆▇▇████</td></tr><tr><td>outer_idx</td><td>▁</td></tr><tr><td>value_w_blue</td><td>▁</td></tr><tr><td>value_w_red</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/cardinality</td><td>1</td></tr><tr><td>eval/eum</td><td>0</td></tr><tr><td>eval/hypervolume</td><td>0</td></tr><tr><td>front_size</td><td>1</td></tr><tr><td>global_step</td><td>100</td></tr><tr><td>outer_idx</td><td>1</td></tr><tr><td>value_w_blue</td><td>0.11111</td></tr><tr><td>value_w_red</td><td>0.88889</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">my-four-room-v0__Pareto Q-Learning__42__1775654758</strong> at: <a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/v55p9y0y' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines/runs/v55p9y0y</a><br> View project at: <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines</a><br>Synced 6 W&B file(s), 11 media file(s), 7 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260408_152600-v55p9y0y\logs</code>
# Tracking run with wandb version 0.24.2
# Run data is saved locally in <code>c:\Users\skakr\Documents\Programming\md-morl\wandb\run-20260408_152608-7xda7si8</code>
# Syncing run <strong><a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/7xda7si8' target="_blank">my-four-room-v0__Pareto Q-Learning__42__1775654767</a></strong> to <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines</a>
#  View run at <a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/7xda7si8' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines/runs/7xda7si8</a>
# c:\Users\skakr\Documents\Programming\md-morl\.venv\Lib\site-packages\gymnasium\utils\passive_env_checker.py:245: UserWarning: WARN: The reward returned by `step()` must be a float, int, np.integer or np.floating, actual type: <class 'numpy.ndarray'>
#   logger.warn(
# [3/10] value weights (blue=0.222, red=0.778) -> front size=1
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/cardinality</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/eum</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/hypervolume</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>front_size</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁▂▂▃▃▃▃▄▄▅▅▆▆▆▆▇▇████</td></tr><tr><td>outer_idx</td><td>▁</td></tr><tr><td>value_w_blue</td><td>▁</td></tr><tr><td>value_w_red</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/cardinality</td><td>1</td></tr><tr><td>eval/eum</td><td>0</td></tr><tr><td>eval/hypervolume</td><td>0</td></tr><tr><td>front_size</td><td>1</td></tr><tr><td>global_step</td><td>100</td></tr><tr><td>outer_idx</td><td>2</td></tr><tr><td>value_w_blue</td><td>0.22222</td></tr><tr><td>value_w_red</td><td>0.77778</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">my-four-room-v0__Pareto Q-Learning__42__1775654767</strong> at: <a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/7xda7si8' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines/runs/7xda7si8</a><br> View project at: <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines</a><br>Synced 6 W&B file(s), 11 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260408_152608-7xda7si8\logs</code>
# Tracking run with wandb version 0.24.2
# Run data is saved locally in <code>c:\Users\skakr\Documents\Programming\md-morl\wandb\run-20260408_152620-agwdowdw</code>
# Syncing run <strong><a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/agwdowdw' target="_blank">my-four-room-v0__Pareto Q-Learning__42__1775654779</a></strong> to <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines</a>
#  View run at <a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/agwdowdw' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines/runs/agwdowdw</a>
# c:\Users\skakr\Documents\Programming\md-morl\.venv\Lib\site-packages\gymnasium\utils\passive_env_checker.py:245: UserWarning: WARN: The reward returned by `step()` must be a float, int, np.integer or np.floating, actual type: <class 'numpy.ndarray'>
#   logger.warn(
# [4/10] value weights (blue=0.333, red=0.667) -> front size=1
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/cardinality</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/eum</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/hypervolume</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>front_size</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁▂▂▃▃▃▃▄▄▅▅▆▆▆▆▇▇████</td></tr><tr><td>outer_idx</td><td>▁</td></tr><tr><td>value_w_blue</td><td>▁</td></tr><tr><td>value_w_red</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/cardinality</td><td>1</td></tr><tr><td>eval/eum</td><td>0</td></tr><tr><td>eval/hypervolume</td><td>0</td></tr><tr><td>front_size</td><td>1</td></tr><tr><td>global_step</td><td>100</td></tr><tr><td>outer_idx</td><td>3</td></tr><tr><td>value_w_blue</td><td>0.33333</td></tr><tr><td>value_w_red</td><td>0.66667</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">my-four-room-v0__Pareto Q-Learning__42__1775654779</strong> at: <a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/agwdowdw' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines/runs/agwdowdw</a><br> View project at: <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines</a><br>Synced 6 W&B file(s), 11 media file(s), 7 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260408_152620-agwdowdw\logs</code>
# Tracking run with wandb version 0.24.2
# Run data is saved locally in <code>c:\Users\skakr\Documents\Programming\md-morl\wandb\run-20260408_152631-4vhpvnmk</code>
# Syncing run <strong><a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/4vhpvnmk' target="_blank">my-four-room-v0__Pareto Q-Learning__42__1775654790</a></strong> to <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines</a>
#  View run at <a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/4vhpvnmk' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines/runs/4vhpvnmk</a>
# c:\Users\skakr\Documents\Programming\md-morl\.venv\Lib\site-packages\gymnasium\utils\passive_env_checker.py:245: UserWarning: WARN: The reward returned by `step()` must be a float, int, np.integer or np.floating, actual type: <class 'numpy.ndarray'>
#   logger.warn(
# [5/10] value weights (blue=0.444, red=0.556) -> front size=1
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/cardinality</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/eum</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/hypervolume</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>front_size</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁▂▂▃▃▃▃▄▄▅▅▆▆▆▆▇▇████</td></tr><tr><td>outer_idx</td><td>▁</td></tr><tr><td>value_w_blue</td><td>▁</td></tr><tr><td>value_w_red</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/cardinality</td><td>1</td></tr><tr><td>eval/eum</td><td>0</td></tr><tr><td>eval/hypervolume</td><td>0</td></tr><tr><td>front_size</td><td>1</td></tr><tr><td>global_step</td><td>100</td></tr><tr><td>outer_idx</td><td>4</td></tr><tr><td>value_w_blue</td><td>0.44444</td></tr><tr><td>value_w_red</td><td>0.55556</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">my-four-room-v0__Pareto Q-Learning__42__1775654790</strong> at: <a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/4vhpvnmk' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines/runs/4vhpvnmk</a><br> View project at: <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines</a><br>Synced 6 W&B file(s), 11 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260408_152631-4vhpvnmk\logs</code>
# Tracking run with wandb version 0.24.2
# Run data is saved locally in <code>c:\Users\skakr\Documents\Programming\md-morl\wandb\run-20260408_152644-bb3gm12f</code>
# Syncing run <strong><a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/bb3gm12f' target="_blank">my-four-room-v0__Pareto Q-Learning__42__1775654802</a></strong> to <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines</a>
#  View run at <a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/bb3gm12f' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines/runs/bb3gm12f</a>
# c:\Users\skakr\Documents\Programming\md-morl\.venv\Lib\site-packages\gymnasium\utils\passive_env_checker.py:245: UserWarning: WARN: The reward returned by `step()` must be a float, int, np.integer or np.floating, actual type: <class 'numpy.ndarray'>
#   logger.warn(
# [6/10] value weights (blue=0.556, red=0.444) -> front size=1
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/cardinality</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/eum</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/hypervolume</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>front_size</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁▂▂▃▃▃▃▄▄▅▅▆▆▆▆▇▇████</td></tr><tr><td>outer_idx</td><td>▁</td></tr><tr><td>value_w_blue</td><td>▁</td></tr><tr><td>value_w_red</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/cardinality</td><td>1</td></tr><tr><td>eval/eum</td><td>0</td></tr><tr><td>eval/hypervolume</td><td>0</td></tr><tr><td>front_size</td><td>1</td></tr><tr><td>global_step</td><td>100</td></tr><tr><td>outer_idx</td><td>5</td></tr><tr><td>value_w_blue</td><td>0.55556</td></tr><tr><td>value_w_red</td><td>0.44444</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">my-four-room-v0__Pareto Q-Learning__42__1775654802</strong> at: <a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/bb3gm12f' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines/runs/bb3gm12f</a><br> View project at: <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines</a><br>Synced 6 W&B file(s), 11 media file(s), 7 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260408_152644-bb3gm12f\logs</code>
# Tracking run with wandb version 0.24.2
# Run data is saved locally in <code>c:\Users\skakr\Documents\Programming\md-morl\wandb\run-20260408_152654-jvn5qb0e</code>
# Syncing run <strong><a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/jvn5qb0e' target="_blank">my-four-room-v0__Pareto Q-Learning__42__1775654813</a></strong> to <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines</a>
#  View run at <a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/jvn5qb0e' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines/runs/jvn5qb0e</a>
# c:\Users\skakr\Documents\Programming\md-morl\.venv\Lib\site-packages\gymnasium\utils\passive_env_checker.py:245: UserWarning: WARN: The reward returned by `step()` must be a float, int, np.integer or np.floating, actual type: <class 'numpy.ndarray'>
#   logger.warn(
# [7/10] value weights (blue=0.667, red=0.333) -> front size=1
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/cardinality</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/eum</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/hypervolume</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>front_size</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁▂▂▃▃▃▃▄▄▅▅▆▆▆▆▇▇████</td></tr><tr><td>outer_idx</td><td>▁</td></tr><tr><td>value_w_blue</td><td>▁</td></tr><tr><td>value_w_red</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/cardinality</td><td>1</td></tr><tr><td>eval/eum</td><td>0</td></tr><tr><td>eval/hypervolume</td><td>0</td></tr><tr><td>front_size</td><td>1</td></tr><tr><td>global_step</td><td>100</td></tr><tr><td>outer_idx</td><td>6</td></tr><tr><td>value_w_blue</td><td>0.66667</td></tr><tr><td>value_w_red</td><td>0.33333</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">my-four-room-v0__Pareto Q-Learning__42__1775654813</strong> at: <a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/jvn5qb0e' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines/runs/jvn5qb0e</a><br> View project at: <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines</a><br>Synced 6 W&B file(s), 11 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260408_152654-jvn5qb0e\logs</code>
# Tracking run with wandb version 0.24.2
# Run data is saved locally in <code>c:\Users\skakr\Documents\Programming\md-morl\wandb\run-20260408_152707-o68kqf58</code>
# Syncing run <strong><a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/o68kqf58' target="_blank">my-four-room-v0__Pareto Q-Learning__42__1775654826</a></strong> to <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines</a>
#  View run at <a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/o68kqf58' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines/runs/o68kqf58</a>
# c:\Users\skakr\Documents\Programming\md-morl\.venv\Lib\site-packages\gymnasium\utils\passive_env_checker.py:245: UserWarning: WARN: The reward returned by `step()` must be a float, int, np.integer or np.floating, actual type: <class 'numpy.ndarray'>
#   logger.warn(
# [8/10] value weights (blue=0.778, red=0.222) -> front size=1
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/cardinality</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/eum</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/hypervolume</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>front_size</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁▂▂▃▃▃▃▄▄▅▅▆▆▆▆▇▇████</td></tr><tr><td>outer_idx</td><td>▁</td></tr><tr><td>value_w_blue</td><td>▁</td></tr><tr><td>value_w_red</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/cardinality</td><td>1</td></tr><tr><td>eval/eum</td><td>0</td></tr><tr><td>eval/hypervolume</td><td>0</td></tr><tr><td>front_size</td><td>1</td></tr><tr><td>global_step</td><td>100</td></tr><tr><td>outer_idx</td><td>7</td></tr><tr><td>value_w_blue</td><td>0.77778</td></tr><tr><td>value_w_red</td><td>0.22222</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">my-four-room-v0__Pareto Q-Learning__42__1775654826</strong> at: <a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/o68kqf58' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines/runs/o68kqf58</a><br> View project at: <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines</a><br>Synced 6 W&B file(s), 11 media file(s), 7 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260408_152707-o68kqf58\logs</code>
# Tracking run with wandb version 0.24.2
# Run data is saved locally in <code>c:\Users\skakr\Documents\Programming\md-morl\wandb\run-20260408_152718-ncnx3sjy</code>
# Syncing run <strong><a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/ncnx3sjy' target="_blank">my-four-room-v0__Pareto Q-Learning__42__1775654837</a></strong> to <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines</a>
#  View run at <a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/ncnx3sjy' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines/runs/ncnx3sjy</a>
# c:\Users\skakr\Documents\Programming\md-morl\.venv\Lib\site-packages\gymnasium\utils\passive_env_checker.py:245: UserWarning: WARN: The reward returned by `step()` must be a float, int, np.integer or np.floating, actual type: <class 'numpy.ndarray'>
#   logger.warn(
# [9/10] value weights (blue=0.889, red=0.111) -> front size=1
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/cardinality</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/eum</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/hypervolume</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>front_size</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁▂▂▃▃▃▃▄▄▅▅▆▆▆▆▇▇████</td></tr><tr><td>outer_idx</td><td>▁</td></tr><tr><td>value_w_blue</td><td>▁</td></tr><tr><td>value_w_red</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/cardinality</td><td>1</td></tr><tr><td>eval/eum</td><td>0</td></tr><tr><td>eval/hypervolume</td><td>0</td></tr><tr><td>front_size</td><td>1</td></tr><tr><td>global_step</td><td>100</td></tr><tr><td>outer_idx</td><td>8</td></tr><tr><td>value_w_blue</td><td>0.88889</td></tr><tr><td>value_w_red</td><td>0.11111</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">my-four-room-v0__Pareto Q-Learning__42__1775654837</strong> at: <a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/ncnx3sjy' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines/runs/ncnx3sjy</a><br> View project at: <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines</a><br>Synced 6 W&B file(s), 11 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260408_152718-ncnx3sjy\logs</code>
# Tracking run with wandb version 0.24.2
# Run data is saved locally in <code>c:\Users\skakr\Documents\Programming\md-morl\wandb\run-20260408_152735-rfusqddy</code>
# Syncing run <strong><a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/rfusqddy' target="_blank">my-four-room-v0__Pareto Q-Learning__42__1775654854</a></strong> to <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines</a>
#  View run at <a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/rfusqddy' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines/runs/rfusqddy</a>
# c:\Users\skakr\Documents\Programming\md-morl\.venv\Lib\site-packages\gymnasium\utils\passive_env_checker.py:245: UserWarning: WARN: The reward returned by `step()` must be a float, int, np.integer or np.floating, actual type: <class 'numpy.ndarray'>
#   logger.warn(
# [10/10] value weights (blue=1.000, red=0.000) -> front size=1
# Done. Collected fronts for 10 value weights.

# %%
# Optional: inspect one front (example for w_blue ~= 0.5)
example_key = min(all_fronts.keys(), key=lambda x: abs(x - 0.5))
example_front = all_fronts[example_key]

print(f"Example key: w_blue={example_key:.3f}, points={len(example_front)}")
print(example_front[:10])

# %%
all_fronts = {}

w_blue = 0.5
w_red = 1.0 - w_blue
weight_vec = np.array([w_blue, w_red], dtype=np.float32)
i = 0

train_env = CombineWrapper(Convert2DStateWrapper(gym.wrappers.TimeLimit(gym.make("my-four-room-v0"), max_episode_steps=MAX_EPISODE_STEPS)), weight_vec)
eval_env = CombineWrapper(Convert2DStateWrapper(gym.wrappers.TimeLimit(gym.make("my-four-room-v0"), max_episode_steps=MAX_EPISODE_STEPS)), weight_vec)

agent = PQL(
    env=train_env,
    ref_point=REF_POINT,
    gamma=0.99,
    initial_epsilon=1.0,
    epsilon_decay_steps=TOTAL_TIMESTEPS,
    final_epsilon=0.05,
    seed=SEED,
    log=True,
)

print(f"Training PQL for {TOTAL_TIMESTEPS} timesteps")
pareto_front = agent.train(
    total_timesteps=TOTAL_TIMESTEPS,
    eval_env=eval_env,
    ref_point=REF_POINT,
    log_every=max(1, TOTAL_TIMESTEPS // 10),
    action_eval="hypervolume",
)
print("Done training PQL")

front_arr = np.array(list(pareto_front), dtype=np.float32)
all_fronts[float(w_blue)] = front_arr

# Per-weight logging in one shared run
wandb.log({
    "outer_idx": i,
    "value_w_blue": float(w_blue),
    "value_w_red": float(w_red),
    "front_size": int(len(front_arr)),
})

visualize_front_general(front_arr, columns=["triangle", "circle"])

print(
    f"[{i + 1}/{N_WEIGHTS}] value weights (blue={w_blue:.3f}, red={w_red:.3f}) -> "
    f"front size={len(front_arr)}"
)

train_env.close()
eval_env.close()

wandb.log({"n_fronts_collected": len(all_fronts)})

# Aggregate visualization logged in the same run
fig, ax = plt.subplots(figsize=(8, 6))
for w_blue, front in all_fronts.items():
    ax.scatter(front[:, 0], front[:, 1], alpha=0.7, label=f"w_blue={w_blue:.2f}")

    ax.set_xlabel("triangle interpretation")
    ax.set_ylabel("circle interpretation")
    ax.set_title("Pareto fronts over interpretations per value scalarization weight")
    ax.legend(loc="best", fontsize=8, ncol=2)
    ax.grid(True, alpha=0.3)
    plt.tight_layout()

    wandb.log({"all_fronts_overlay": wandb.Image(fig)})
    plt.close(fig)

    print("Done. Collected fronts for", len(all_fronts), "value weights.")
# Out:
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">my-four-room-v0__Pareto Q-Learning__42__1775655965</strong> at: <a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/db8nfifm' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines/runs/db8nfifm</a><br> View project at: <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines</a><br>Synced 6 W&B file(s), 0 media file(s), 7 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260408_154606-db8nfifm\logs</code>
# Tracking run with wandb version 0.24.2
# Run data is saved locally in <code>c:\Users\skakr\Documents\Programming\md-morl\wandb\run-20260408_154644-7gd1zqrf</code>
# Syncing run <strong><a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/7gd1zqrf' target="_blank">my-four-room-v0__Pareto Q-Learning__42__1775656003</a></strong> to <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/kristofs-ai/MORL-Baselines' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines</a>
#  View run at <a href='https://wandb.ai/kristofs-ai/MORL-Baselines/runs/7gd1zqrf' target="_blank">https://wandb.ai/kristofs-ai/MORL-Baselines/runs/7gd1zqrf</a>
# Training PQL for 10000 timesteps
# c:\Users\skakr\Documents\Programming\md-morl\.venv\Lib\site-packages\gymnasium\utils\passive_env_checker.py:245: UserWarning: WARN: The reward returned by `step()` must be a float, int, np.integer or np.floating, actual type: <class 'numpy.ndarray'>
#   logger.warn(
# Done training PQL
# [1/10] value weights (blue=0.500, red=0.500) -> front size=2
# Done. Collected fronts for 1 value weights.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
